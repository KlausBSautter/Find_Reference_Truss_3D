# %%
from base_functions import node, element_linear, element_nonlinear, system

#### linear trusses 

n0  =  node(id= 0 ,coord=[ -5.0 , -2.5, 0],aim_coord=[ -5.0 , -2.5, 0 ],force=[0,0, 0],dofs=[ 0 , 1 ,2 ],fix=[True,True,True])
n1  =  node(id= 1 ,coord=[ -3.888888888888889 , -1.5123456790123457, 0 ],aim_coord=[ -3.888888888888889 , -1.5123456790123457, 0 ],force=[0,0, 0],dofs=[  3,4,5 ],fix=[False,False,True])
n2  =  node(id= 2 ,coord=[ -2.7777777777777777 , -0.7716049382716049, 0 ],aim_coord=[ -2.7777777777777777 , -0.7716049382716049, 0 ],force=[0,0, 0],dofs=[ 6,7,8 ],fix=[False,False,True])
n3  =  node(id= 3 ,coord=[ -1.6666666666666665 , -0.27777777777777773, 0 ],aim_coord=[ -1.6666666666666665 , -0.27777777777777773, 0 ],force=[0,0, 0],dofs=[ 9,10,11 ],fix=[False,False,True])
n4  =  node(id= 4 ,coord=[ -0.5555555555555554 , -0.030864197530864175, 0 ],aim_coord=[ -0.5555555555555554 , -0.030864197530864175, 0 ],force=[0,0, 0],dofs=[ 12,13,14 ],fix=[False,False,True])
n5  =  node(id= 5 ,coord=[ 0.5555555555555554 , -0.030864197530864175 , 0],aim_coord=[ 0.5555555555555554 , -0.030864197530864175, 0 ],force=[0,0, 0],dofs=[ 15,16,17 ],fix=[False,False,True])
n6  =  node(id= 6 ,coord=[ 1.666666666666667 , -0.27777777777777785, 0],aim_coord=[ 1.666666666666667 , -0.27777777777777785, 0 ],force=[0,0, 0],dofs=[ 18,19,20 ],fix=[False,False,True])
n7  =  node(id= 7 ,coord=[ 2.7777777777777786 , -0.7716049382716054, 0 ],aim_coord=[ 2.7777777777777786 , -0.7716049382716054 , 0],force=[0,0, 0],dofs=[ 21,22,23 ],fix=[False,False,True])
n8  =  node(id= 8 ,coord=[ 3.8888888888888893 , -1.512345679012346 , 0],aim_coord=[ 3.8888888888888893 , -1.512345679012346 , 0],force=[0,0, 0],dofs=[ 24,25,26 ],fix=[False,False,True])
n9  =  node(id= 9 ,coord=[ 5.0 , -2.5 , 0],aim_coord=[ 5.0 , -2.5, 0 ],force=[0,0],dofs=[ 27,28,29 ],fix=[True,True,True])
n10  =  node(id= 10 ,coord=[ -5.707106781186548 , -1.7928932188134525, 0 ],aim_coord=[ -5.707106781186548 , -1.7928932188134525, 0 ],force=[0,0, 0],dofs=[ 30,31,32 ],fix=[False,False,True])
n11  =  node(id= 11 ,coord=[ -4.502829502403809 , -0.7229934616360194, 0 ],aim_coord=[ -4.502829502403809 , -0.7229934616360194, 0 ],force=[0,0, 0],dofs=[ 33,34,35 ],fix=[False,False,True])
n12  =  node(id= 12 ,coord=[ -3.26342070895641 , 0.10255233784993278, 0 ],aim_coord=[ -3.26342070895641 , 0.10255233784993278, 0 ],force=[0,0, 0],dofs=[ 36,37,38 ],fix=[False,False,True])
n13  =  node(id= 13 ,coord=[ -1.9828944326835045 , 0.6709055202727361, 0 ],aim_coord=[ -1.9828944326835045 , 0.6709055202727361 , 0],force=[0,0, 0],dofs=[ 39,40,41 ],fix=[False,False,True])
n14  =  node(id= 14 ,coord=[ -0.6659870816304019 , 0.9630195371427547, 0 ],aim_coord=[ -0.6659870816304019 , 0.9630195371427547 , 0],force=[0,0, 0],dofs=[ 42,43,44 ],fix=[False,False,True])
n15  =  node(id= 15 ,coord=[ 0.6659870816304019 , 0.9630195371427547, 0 ],aim_coord=[ 0.6659870816304019 , 0.9630195371427547 , 0],force=[0,100, 0],dofs=[ 45,46,47 ],fix=[False,False,True])
n16  =  node(id= 16 ,coord=[ 1.982894432683505 , 0.6709055202727359 , 0],aim_coord=[ 1.982894432683505 , 0.6709055202727359 , 0],force=[0,0, 0],dofs=[ 48,49,50 ],fix=[False,False,True])
n17  =  node(id= 17 ,coord=[ 3.263420708956411 , 0.10255233784993234, 0 ],aim_coord=[ 3.263420708956411 , 0.10255233784993234, 0 ],force=[0,100, 0],dofs=[ 51,52,53 ],fix=[False,False,True])
n18  =  node(id= 18 ,coord=[ 4.502829502403809 , -0.7229934616360196 , 0],aim_coord=[ 4.502829502403809 , -0.7229934616360196, 0 ],force=[0,0, 0],dofs=[ 54,55,56 ],fix=[False,False,True])
n19  =  node(id= 19 ,coord=[ 5.707106781186548 , -1.7928932188134525, 0],aim_coord=[ 5.707106781186548 , -1.7928932188134525 , 0],force=[0,0, 0],dofs=[ 57,58,59 ],fix=[False,False,True])

mp = {
    "claw": "StVenant",
    "YoungsModulus" : 300000.0
}

e0 = element_linear(n0 ,n1 , material_parameters=mp, cross_area=0.01)
e1 = element_linear(n1 ,n2 , material_parameters=mp, cross_area=0.01)
e2 = element_linear(n2 ,n3 , material_parameters=mp, cross_area=0.01)
e3 = element_linear(n3 ,n4 , material_parameters=mp, cross_area=0.01)
e4 = element_linear(n4 ,n5 , material_parameters=mp, cross_area=0.01)
e5 = element_linear(n5 ,n6 , material_parameters=mp, cross_area=0.01)
e6 = element_linear(n6 ,n7 , material_parameters=mp, cross_area=0.01)
e7 = element_linear(n7 ,n8 , material_parameters=mp, cross_area=0.01)
e8 = element_linear(n8 ,n9 , material_parameters=mp, cross_area=0.01)

e10 = element_linear(n10 ,n11 , material_parameters=mp, cross_area=0.01)
e11 = element_linear(n11 ,n12 , material_parameters=mp, cross_area=0.01)
e12 = element_linear(n12 ,n13 , material_parameters=mp, cross_area=0.01)
e13 = element_linear(n13 ,n14 , material_parameters=mp, cross_area=0.01)
e14 = element_linear(n14 ,n15 , material_parameters=mp, cross_area=0.01)
e15 = element_linear(n15 ,n16 , material_parameters=mp, cross_area=0.01)
e16 = element_linear(n16 ,n17 , material_parameters=mp, cross_area=0.01)
e17 = element_linear(n17 ,n18 , material_parameters=mp, cross_area=0.01)
e18 = element_linear(n18 ,n19 , material_parameters=mp, cross_area=0.01)

e20 = element_linear(n0 ,n10 , material_parameters=mp, cross_area=0.01)
e21 = element_linear(n1 ,n11 , material_parameters=mp, cross_area=0.01)
e22 = element_linear(n2 ,n12 , material_parameters=mp, cross_area=0.01)
e23 = element_linear(n3 ,n13 , material_parameters=mp, cross_area=0.01)
e24 = element_linear(n4 ,n14 , material_parameters=mp, cross_area=0.01)
e25 = element_linear(n5 ,n15 , material_parameters=mp, cross_area=0.01)
e26 = element_linear(n6 ,n16 , material_parameters=mp, cross_area=0.01)
e27 = element_linear(n7 ,n17 , material_parameters=mp, cross_area=0.01)
e28 = element_linear(n8 ,n18 , material_parameters=mp, cross_area=0.01)
e29 = element_linear(n9 ,n19 , material_parameters=mp, cross_area=0.01)

e30 = element_linear(n0 ,n11 , material_parameters=mp, cross_area=0.01)
e31 = element_linear(n1 ,n12 , material_parameters=mp, cross_area=0.01)
e32 = element_linear(n2 ,n13 , material_parameters=mp, cross_area=0.01)
e33 = element_linear(n3 ,n14 , material_parameters=mp, cross_area=0.01)
e34 = element_linear(n4 ,n15 , material_parameters=mp, cross_area=0.01)
e35 = element_linear(n5 ,n16 , material_parameters=mp, cross_area=0.01)
e36 = element_linear(n6 ,n17 , material_parameters=mp, cross_area=0.01)
e37 = element_linear(n7 ,n18 , material_parameters=mp, cross_area=0.01)
e38 = element_linear(n8 ,n19 , material_parameters=mp, cross_area=0.01)


s_l = system(
    [n0,n1,n2,n3,n4,n5,n6,n7,n8,n9,n10,n11,n12,n13,n14,n15,n16,n17,n18,n19],
    [e0,e1,e2,e3,e4,e5,e6,e7,e8,e10,e11,e12,e13,e14,e15,e16,e17,e18,e20,e21,e22,e23,e24,e25,e26,e27,e28,e29,e30,e31,e32,e33,e34,e35,e36,e37,e38])

# %%
#### nonlinear trusses

n00  =  node(id= 0 ,coord=[ -5.0 , -2.5, 0],aim_coord=[ -5.0 , -2.5, 0 ],force=[0,0, 0],dofs=[ 0 , 1 ,2 ],fix=[True,True,True])
n01  =  node(id= 1 ,coord=[ -3.888888888888889 , -1.5123456790123457, 0 ],aim_coord=[ -3.888888888888889 , -1.5123456790123457, 0 ],force=[0,0, 0],dofs=[  3,4,5 ],fix=[False,False,True])
n02  =  node(id= 2 ,coord=[ -2.7777777777777777 , -0.7716049382716049, 0 ],aim_coord=[ -2.7777777777777777 , -0.7716049382716049, 0 ],force=[0,0, 0],dofs=[ 6,7,8 ],fix=[False,False,True])
n03  =  node(id= 3 ,coord=[ -1.6666666666666665 , -0.27777777777777773, 0 ],aim_coord=[ -1.6666666666666665 , -0.27777777777777773, 0 ],force=[0,0, 0],dofs=[ 9,10,11 ],fix=[False,False,True])
n04  =  node(id= 4 ,coord=[ -0.5555555555555554 , -0.030864197530864175, 0 ],aim_coord=[ -0.5555555555555554 , -0.030864197530864175, 0 ],force=[0,0, 0],dofs=[ 12,13,14 ],fix=[False,False,True])
n05  =  node(id= 5 ,coord=[ 0.5555555555555554 , -0.030864197530864175 , 0],aim_coord=[ 0.5555555555555554 , -0.030864197530864175, 0 ],force=[0,0, 0],dofs=[ 15,16,17 ],fix=[False,False,True])
n06  =  node(id= 6 ,coord=[ 1.666666666666667 , -0.27777777777777785, 0],aim_coord=[ 1.666666666666667 , -0.27777777777777785, 0 ],force=[0,0, 0],dofs=[ 18,19,20 ],fix=[False,False,True])
n07  =  node(id= 7 ,coord=[ 2.7777777777777786 , -0.7716049382716054, 0 ],aim_coord=[ 2.7777777777777786 , -0.7716049382716054 , 0],force=[0,0, 0],dofs=[ 21,22,23 ],fix=[False,False,True])
n08  =  node(id= 8 ,coord=[ 3.8888888888888893 , -1.512345679012346 , 0],aim_coord=[ 3.8888888888888893 , -1.512345679012346 , 0],force=[0,0, 0],dofs=[ 24,25,26 ],fix=[False,False,True])
n09  =  node(id= 9 ,coord=[ 5.0 , -2.5 , 0],aim_coord=[ 5.0 , -2.5, 0 ],force=[0,0],dofs=[ 27,28,29 ],fix=[True,True,True])
n010  =  node(id= 10 ,coord=[ -5.707106781186548 , -1.7928932188134525, 0 ],aim_coord=[ -5.707106781186548 , -1.7928932188134525, 0 ],force=[0,0, 0],dofs=[ 30,31,32 ],fix=[False,False,True])
n011  =  node(id= 11 ,coord=[ -4.502829502403809 , -0.7229934616360194, 0 ],aim_coord=[ -4.502829502403809 , -0.7229934616360194, 0 ],force=[0,0, 0],dofs=[ 33,34,35 ],fix=[False,False,True])
n012  =  node(id= 12 ,coord=[ -3.26342070895641 , 0.10255233784993278, 0 ],aim_coord=[ -3.26342070895641 , 0.10255233784993278, 0 ],force=[0,0, 0],dofs=[ 36,37,38 ],fix=[False,False,True])
n013  =  node(id= 13 ,coord=[ -1.9828944326835045 , 0.6709055202727361, 0 ],aim_coord=[ -1.9828944326835045 , 0.6709055202727361 , 0],force=[0,0, 0],dofs=[ 39,40,41 ],fix=[False,False,True])
n014  =  node(id= 14 ,coord=[ -0.6659870816304019 , 0.9630195371427547, 0 ],aim_coord=[ -0.6659870816304019 , 0.9630195371427547 , 0],force=[0,0, 0],dofs=[ 42,43,44 ],fix=[False,False,True])
n015  =  node(id= 15 ,coord=[ 0.6659870816304019 , 0.9630195371427547, 0 ],aim_coord=[ 0.6659870816304019 , 0.9630195371427547 , 0],force=[0,100, 0],dofs=[ 45,46,47 ],fix=[False,False,True])
n016  =  node(id= 16 ,coord=[ 1.982894432683505 , 0.6709055202727359 , 0],aim_coord=[ 1.982894432683505 , 0.6709055202727359 , 0],force=[0,0, 0],dofs=[ 48,49,50 ],fix=[False,False,True])
n017  =  node(id= 17 ,coord=[ 3.263420708956411 , 0.10255233784993234, 0 ],aim_coord=[ 3.263420708956411 , 0.10255233784993234, 0 ],force=[0,100, 0],dofs=[ 51,52,53 ],fix=[False,False,True])
n018  =  node(id= 18 ,coord=[ 4.502829502403809 , -0.7229934616360196 , 0],aim_coord=[ 4.502829502403809 , -0.7229934616360196, 0 ],force=[0,0, 0],dofs=[ 54,55,56 ],fix=[False,False,True])
n019  =  node(id= 19 ,coord=[ 5.707106781186548 , -1.7928932188134525, 0],aim_coord=[ 5.707106781186548 , -1.7928932188134525 , 0],force=[0,0, 0],dofs=[ 57,58,59 ],fix=[False,False,True])

e00 = element_nonlinear(n00 ,n01 , material_parameters=mp, cross_area=0.01)
e01 = element_nonlinear(n01 ,n02 , material_parameters=mp, cross_area=0.01)
e02 = element_nonlinear(n02 ,n03 , material_parameters=mp, cross_area=0.01)
e03 = element_nonlinear(n03 ,n04 , material_parameters=mp, cross_area=0.01)
e04 = element_nonlinear(n04 ,n05 , material_parameters=mp, cross_area=0.01)
e05 = element_nonlinear(n05 ,n06 , material_parameters=mp, cross_area=0.01)
e06 = element_nonlinear(n06 ,n07 , material_parameters=mp, cross_area=0.01)
e07 = element_nonlinear(n07 ,n08 , material_parameters=mp, cross_area=0.01)
e08 = element_nonlinear(n08 ,n09 , material_parameters=mp, cross_area=0.01)

e010 = element_nonlinear(n010 ,n011 , material_parameters=mp, cross_area=0.01)
e011 = element_nonlinear(n011 ,n012 , material_parameters=mp, cross_area=0.01)
e012 = element_nonlinear(n012 ,n013 , material_parameters=mp, cross_area=0.01)
e013 = element_nonlinear(n013 ,n014 , material_parameters=mp, cross_area=0.01)
e014 = element_nonlinear(n014 ,n015 , material_parameters=mp, cross_area=0.01)
e015 = element_nonlinear(n015 ,n016 , material_parameters=mp, cross_area=0.01)
e016 = element_nonlinear(n016 ,n017 , material_parameters=mp, cross_area=0.01)
e017 = element_nonlinear(n017 ,n018 , material_parameters=mp, cross_area=0.01)
e018 = element_nonlinear(n018 ,n019 , material_parameters=mp, cross_area=0.01)

e020 = element_nonlinear(n00 ,n010 , material_parameters=mp, cross_area=0.01)
e021 = element_nonlinear(n01 ,n011 , material_parameters=mp, cross_area=0.01)
e022 = element_nonlinear(n02 ,n012 , material_parameters=mp, cross_area=0.01)
e023 = element_nonlinear(n03 ,n013 , material_parameters=mp, cross_area=0.01)
e024 = element_nonlinear(n04 ,n014 , material_parameters=mp, cross_area=0.01)
e025 = element_nonlinear(n05 ,n015 , material_parameters=mp, cross_area=0.01)
e026 = element_nonlinear(n06 ,n016 , material_parameters=mp, cross_area=0.01)
e027 = element_nonlinear(n07 ,n017 , material_parameters=mp, cross_area=0.01)
e028 = element_nonlinear(n08 ,n018 , material_parameters=mp, cross_area=0.01)
e029 = element_nonlinear(n09 ,n019 , material_parameters=mp, cross_area=0.01)

e030 = element_nonlinear(n00 ,n011 , material_parameters=mp, cross_area=0.01)
e031 = element_nonlinear(n01 ,n012 , material_parameters=mp, cross_area=0.01)
e032 = element_nonlinear(n02 ,n013 , material_parameters=mp, cross_area=0.01)
e033 = element_nonlinear(n03 ,n014 , material_parameters=mp, cross_area=0.01)
e034 = element_nonlinear(n04 ,n015 , material_parameters=mp, cross_area=0.01)
e035 = element_nonlinear(n05 ,n016 , material_parameters=mp, cross_area=0.01)
e036 = element_nonlinear(n06 ,n017 , material_parameters=mp, cross_area=0.01)
e037 = element_nonlinear(n07 ,n018 , material_parameters=mp, cross_area=0.01)
e038 = element_nonlinear(n08 ,n019 , material_parameters=mp, cross_area=0.01)



s_nl = system(
    [n00,n01,n02,n03,n04,n05,n06,n07,n08,n09,n010,n011,n012,n013,n014,n015,n016,n017,n018,n019],
    [e00,e01,e02,e03,e04,e05,e06,e07,e08,e010,e011,e012,e013,e014,e015,e016,e017,e018,e020,e021,e022,e023,e024,e025,e026,e027,e028,e029,e030,e031,e032,e033,e034,e035,e036,e037,e038])

# %%
# solving nonlinear trusses
s_nl.solve_inverse_problem()

# solving linear trusses
s_l.solve_inverse_problem()
# Out:
#  >> starting to solve inverse problem
# disp residual:  1.372620e+00   |   force residual:  1.414214e+02
# disp residual:  1.649605e-01   |   force residual:  1.683891e+02
# disp residual:  4.738175e-03   |   force residual:  4.624764e+00
# disp residual:  5.406383e-06   |   force residual:  5.621960e-03
# disp residual:  9.166323e-12   |   force residual:  1.341998e-08
# disp residual:  1.171796e-15   |   force residual:  4.919410e-12
#  >> inverse problem solved
#  >> starting to solve inverse problem
# disp residual:  1.372620e+00   |   force residual:  1.414214e+02
# disp residual:  8.943813e-01   |   force residual:  3.416530e+02
# disp residual:  7.792824e-01   |   force residual:  1.255386e+02
# disp residual:  4.938294e-01   |   force residual:  1.087642e+02
# disp residual:  3.186129e-01   |   force residual:  4.260420e+01
# disp residual:  9.458896e-02   |   force residual:  1.703439e+01
# disp residual:  1.164433e-02   |   force residual:  1.432679e+00
# ...

# %%
s_nl.plot_convergence(label_text="nonlinear truss")
s_l.plot_convergence(label_text="linear truss")
s_l.show_plot()
#s_l.save_plot_pdf(filename="convergence_plot")

# %%
s_l.solve_original_problem_linear()
s_nl.solve_original_problem_nonlinear()
# Out:
#  >> starting to solve original problem
#  >> original problem solved
#  >> starting to solve original problem
# disp residual:  2.164129e+00   |   force residual:  1.414214e+02
# disp residual:  5.657741e-01   |   force residual:  4.537070e+02
# disp residual:  2.235187e-01   |   force residual:  4.334234e+01
# disp residual:  1.660380e-02   |   force residual:  5.601466e+00
# disp residual:  1.409243e-04   |   force residual:  3.305011e-02
# disp residual:  7.582430e-09   |   force residual:  2.447504e-06
# disp residual:  1.976669e-15   |   force residual:  3.513071e-12
#  >> original problem solved

# %%
s_l.plot2d(["aim","ref","extra"],scale_force=0.05,scale_arrow=0.5,print_lvl=0,proj="z")
s_nl.plot2d(["aim","ref","extra"],scale_force=0.05,scale_arrow=0.5,print_lvl=0,proj="z")
s_l.show_plot()
#s_l.save_plot_pdf(filename="deformation_plot")
